# %%
from tombo import tombo_helper, tombo_stats, resquiggle

# %%
# Out:
# ...
#      |████████████████████████████████| 377 kB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 6.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.9 MB 5.0 MB/s eta 0:00:01
# ...
# Processing /Users/ptdolan/Library/Caches/pip/wheels/bc/3e/d0/6f861d46f085c99d4de1128dc9c020a80ad206a85d638f5cf1/mappy-2.17-cp38-cp38-macosx_10_9_x86_64.whl
# ...
#   Using cached future-0.18.2.tar.gz (829 kB)
# ...
#      |████████████████████████████████| 68 kB 17.4 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
/bin/env bash

tombo preprocess annotate_raw_with_fastqs --fast5-basedir /Library/MinKNOW/data/SARS2/A549_SCoV2_totRNA/20200731_2123_MN34223_FAO33670_43d615e8/fast5_pass/
--fastq-filenames

tombo resquiggle /Library/MinKNOW/data/SARS2/A549_SCoV2_totRNA/20200731_2123_MN34223_FAO33670_43d615e8/fast5_pass/   --processes 4 --num-most-common-errors 5

tombo detect_modifications alternative_model --alternate-bases 5mC 6mA --fast5-basedirs /Library/MinKNOW/data/SARS2/A549_SCoV2_totRNA/20200731_2123_MN34223_FAO33670_43d615e8/fast5_pass/ \
   --statistics-file-basename SARS-CoV-2_vRNAmethylation \
   --processes 6
