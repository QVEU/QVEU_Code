# %%
#Examples from: https://www.pymc.io/projects/docs/en/latest/learn/core_notebooks/pymc_overview.html

#running in 3.9.6 python module locally
# !pip install arviz
# !pip install numpy
# !pip install pymc
# Out:
# Requirement already satisfied: arviz in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: setuptools>=60.0.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (3.7.0)
# Requirement already satisfied: numpy<2.0,>=1.23.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (1.23.5)
# Requirement already satisfied: scipy>=1.9.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (1.10.0)
# Requirement already satisfied: packaging in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (22.0)
# Requirement already satisfied: pandas>=1.5.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (1.5.3)
# Requirement already satisfied: dm-tree>=0.1.8 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (0.1.8)
# Requirement already satisfied: xarray>=2022.6.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (2022.11.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (4.4.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz) (0.7.0)
# Requirement already satisfied: h5py in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pandas>=1.5.0->arviz) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->arviz) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (1.23.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pymc in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (5.14.0)
# Requirement already satisfied: arviz>=0.13.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (0.18.0)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (5.3.3)
# Requirement already satisfied: cloudpickle in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (2.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (1.23.5)
# Requirement already satisfied: pandas>=0.24.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (1.5.3)
# Requirement already satisfied: pytensor<2.21,>=2.20 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (2.20.0)
# Requirement already satisfied: rich>=13.7.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (13.7.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (1.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pymc) (4.4.0)
# Requirement already satisfied: setuptools>=60.0.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (68.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (3.7.0)
# Requirement already satisfied: packaging in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (22.0)
# Requirement already satisfied: dm-tree>=0.1.8 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (0.1.8)
# Requirement already satisfied: xarray>=2022.6.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (2022.11.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (1.3.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from arviz>=0.13.0->pymc) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pandas>=0.24.0->pymc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pandas>=0.24.0->pymc) (2022.7)
# Requirement already satisfied: filelock in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc) (3.9.0)
# Requirement already satisfied: etuples in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc) (1.0.3)
# Requirement already satisfied: cons in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from pytensor<2.21,>=2.20->pymc) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from rich>=13.7.1->pymc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from rich>=13.7.1->pymc) (2.18.0)
# Requirement already satisfied: h5py in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->pymc) (1.16.0)
# Requirement already satisfied: toolz in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->pymc) (0.12.0)
# Requirement already satisfied: multipledispatch in /Users/dolanpt/anaconda3/lib/python3.10/site-packages (from logical-unification->pytensor<2.21,>=2.20->pymc) (0.6.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %config InlineBackend.figure_format = 'retina'
# Initialize random number generator
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %%
# True parameter values
alpha, sigma = 1, 1
beta = [1, 2.5]

# Size of dataset
size = 100

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

# Simulate outcome variable
Y = alpha + beta[0] * X1 + beta[1] * X2 + rng.normal(size=size) * sigma

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10, 4))
axes[0].scatter(X1, Y, alpha=0.6)
axes[1].scatter(X2, Y, alpha=0.6)
axes[0].set_ylabel("Y")
axes[0].set_xlabel("X1")
axes[1].set_xlabel("X2");

# %%
import pymc as pm

print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v5.14.0

# %%
basic_model = pm.Model()

with basic_model:
    # Priors for unknown model parameters
    alpha = pm.Normal("alpha", mu=0, sigma=10)
    beta = pm.Normal("beta", mu=0, sigma=10, shape=2)
    sigma = pm.HalfNormal("sigma", sigma=1)

    # Expected value of outcome
    mu = alpha + beta[0] * X1 + beta[1] * X2

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=Y)

# %%
with basic_model:
    # draw 1000 posterior samples
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 62 seconds.

# %%
az.plot_trace(idata, combined=True);
