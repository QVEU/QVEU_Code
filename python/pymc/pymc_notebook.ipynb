# %%
#Examples from: https://www.pymc.io/projects/docs/en/latest/learn/core_notebooks/pymc_overview.html

#running in 3.9.6 python module locally
# !pip install arviz
# !pip install numpy
# !pip install pymc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: arviz in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (0.17.1)
# Requirement already satisfied: setuptools>=60.0.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (69.5.1)
# Requirement already satisfied: matplotlib>=3.5 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (3.8.2)
# Requirement already satisfied: numpy<2.0,>=1.22.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (1.26.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (1.11.4)
# Requirement already satisfied: packaging in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (2.1.3)
# Requirement already satisfied: xarray>=0.21.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (2024.3.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (4.7.1)
# Requirement already satisfied: xarray-einstats>=0.3 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz) (0.7.0)
# Requirement already satisfied: h5py in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from h5netcdf>=1.0.2->arviz) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->arviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->arviz) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->arviz) (3.16.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->arviz) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (1.26.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymc in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (5.12.0)
# Requirement already satisfied: arviz>=0.13.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (0.17.1)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (5.3.3)
# Requirement already satisfied: cloudpickle in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (3.0.0)
# Requirement already satisfied: fastprogress>=0.2.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (1.26.2)
# Requirement already satisfied: pandas>=0.24.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (2.1.3)
# Requirement already satisfied: pytensor<2.20,>=2.19 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (2.19.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (1.11.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pymc) (4.7.1)
# Requirement already satisfied: setuptools>=60.0.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (69.5.1)
# Requirement already satisfied: matplotlib>=3.5 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (3.8.2)
# Requirement already satisfied: packaging in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (23.1)
# Requirement already satisfied: xarray>=0.21.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (2024.3.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (1.3.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from arviz>=0.13.0->pymc) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=0.24.0->pymc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=0.24.0->pymc) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pandas>=0.24.0->pymc) (2023.3)
# Requirement already satisfied: filelock in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pytensor<2.20,>=2.19->pymc) (3.14.0)
# Requirement already satisfied: etuples in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pytensor<2.20,>=2.19->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pytensor<2.20,>=2.19->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pytensor<2.20,>=2.19->pymc) (1.0.3)
# Requirement already satisfied: cons in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from pytensor<2.20,>=2.19->pymc) (0.4.6)
# Requirement already satisfied: h5py in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (6.1.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.15.0)
# Requirement already satisfied: toolz in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from logical-unification->pytensor<2.20,>=2.19->pymc) (0.12.1)
# Requirement already satisfied: multipledispatch in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from logical-unification->pytensor<2.20,>=2.19->pymc) (1.0.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dolanpt/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->arviz>=0.13.0->pymc) (3.16.2)

# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %config InlineBackend.figure_format = 'retina'
# Initialize random number generator
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %%
# True parameter values
alpha, sigma = 1, 1
beta = [1, 2.5]

# Size of dataset
size = 100

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

# Simulate outcome variable
Y = alpha + beta[0] * X1 + beta[1] * X2 + rng.normal(size=size) * sigma

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10, 4))
axes[0].scatter(X1, Y, alpha=0.6)
axes[1].scatter(X2, Y, alpha=0.6)
axes[0].set_ylabel("Y")
axes[0].set_xlabel("X1")
axes[1].set_xlabel("X2");

# %%
import pymc as pm

print(f"Running on PyMC v{pm.__version__}")
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Running on PyMC v5.12.0

# %%
basic_model = pm.Model()

with basic_model:
    # Priors for unknown model parameters
    alpha = pm.Normal("alpha", mu=0, sigma=10)
    beta = pm.Normal("beta", mu=0, sigma=10, shape=2)
    sigma = pm.HalfNormal("sigma", sigma=1)

    # Expected value of outcome
    mu = alpha + beta[0] * X1 + beta[1] * X2

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=Y)

# %%
with basic_model:
    # draw 1000 posterior samples
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:03&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 26 seconds.

# %%
az.plot_trace(idata, combined=True);
